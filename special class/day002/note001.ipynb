# %% [markdown]
# 머신러닝 : 사람이 학습하는 특징(정답과 관련된)을 지정해줌 => 학습성능이 학습시키는 특징에 따라서 매우 차이남, 한계가 있음
# 딥러닝 : 사람이 발견 못하는 특징들을 기계가 스스로 발견해서 학습하고 이용함  => 특징을 지정해줄 필요가 없음
#
# 인공지능 2분류
# 1. 지식 ->(코드화) 알고리즘 : 지식공학
# 2. 데이터 ->(학습) 알고리즘 : 머신러닝
#
# CNN : 2차원 이미지
# RNN : 연속성 :자연어 분야에서 쓰임
